# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          label
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label_setosa  label_versicolor  label_virginica
# 0            True             False            False
# 1            True             False            False
# 2            True             False            False
# 3            True             False            False
# 4            True             False            False
# ..            ...               ...              ...
# 145         False             False             True
# 146         False             False             True
# 147         False             False             True
# 148         False             False             True
# 149         False             False             True
#
# [150 rows x 7 columns]

# %%
# Creating X and y
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)
y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
batched_model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

# %%
batched_model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
batched_history =  batched_model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 1.0601 - accuracy: 0.5778 - val_loss: 1.0852 - val_accuracy: 0.3667 - 627ms/epoch - 209ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.2379 - accuracy: 0.9556 - val_loss: 1.0571 - val_accuracy: 0.5333 - 19ms/epoch - 6ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.1856 - accuracy: 0.9111 - val_loss: 1.0278 - val_accuracy: 0.5000 - 17ms/epoch - 6ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1219 - accuracy: 0.9889 - val_loss: 1.0044 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.1071 - accuracy: 0.9778 - val_loss: 0.9828 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.1088 - accuracy: 0.9667 - val_loss: 0.9688 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0707 - accuracy: 0.9778 - val_loss: 0.9594 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.0487 - accuracy: 1.0000 - val_loss: 0.9513 - val_accuracy: 0.6333 - 19ms/epoch - 6ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.1393 - accuracy: 0.9444 - val_loss: 0.9419 - val_accuracy: 0.6333 - 16ms/epoch - 5ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0837 - accuracy: 0.9667 - val_loss: 0.9313 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0712 - accuracy: 0.9778 - val_loss: 0.9187 - val_accuracy: 0.6333 - 18ms/epoch - 6ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.8956 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.1170 - accuracy: 0.9667 - val_loss: 0.8601 - val_accuracy: 0.6333 - 18ms/epoch - 6ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.1758 - accuracy: 0.9333 - val_loss: 0.8315 - val_accuracy: 0.6333 - 19ms/epoch - 6ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.0816 - accuracy: 0.9667 - val_loss: 0.7976 - val_accuracy: 0.8000 - 17ms/epoch - 6ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.1012 - accuracy: 0.9667 - val_loss: 0.7832 - val_accuracy: 0.8000 - 17ms/epoch - 6ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0801 - accuracy: 0.9778 - val_loss: 0.7773 - val_accuracy: 0.8000 - 17ms/epoch - 6ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0910 - accuracy: 0.9667 - val_loss: 0.7804 - val_accuracy: 0.8000 - 16ms/epoch - 5ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0416 - accuracy: 0.9889 - val_loss: 0.7809 - val_accuracy: 0.6667 - 17ms/epoch - 6ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0376 - accuracy: 0.9889 - val_loss: 0.7761 - val_accuracy: 0.6667 - 17ms/epoch - 6ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0588 - accuracy: 0.9778 - val_loss: 0.7714 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0815 - accuracy: 0.9556 - val_loss: 0.7689 - val_accuracy: 0.6333 - 16ms/epoch - 5ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0581 - accuracy: 0.9778 - val_loss: 0.7660 - val_accuracy: 0.6333 - 17ms/epoch - 6ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0430 - accuracy: 0.9778 - val_loss: 0.7606 - val_accuracy: 0.6667 - 17ms/epoch - 6ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0457 - accuracy: 0.9889 - val_loss: 0.7537 - val_accuracy: 0.6667 - 17ms/epoch - 6ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.7456 - val_accuracy: 0.7000 - 16ms/epoch - 5ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.7304 - val_accuracy: 0.7333 - 16ms/epoch - 5ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.1267 - accuracy: 0.9778 - val_loss: 0.7108 - val_accuracy: 0.7333 - 16ms/epoch - 5ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0609 - accuracy: 0.9556 - val_loss: 0.6917 - val_accuracy: 0.7667 - 17ms/epoch - 6ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.6740 - val_accuracy: 0.7667 - 17ms/epoch - 6ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.6545 - val_accuracy: 0.8333 - 16ms/epoch - 5ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.1062 - accuracy: 0.9556 - val_loss: 0.6484 - val_accuracy: 0.8333 - 18ms/epoch - 6ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0405 - accuracy: 0.9889 - val_loss: 0.6570 - val_accuracy: 0.7667 - 18ms/epoch - 6ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0460 - accuracy: 0.9778 - val_loss: 0.6615 - val_accuracy: 0.7333 - 18ms/epoch - 6ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.1093 - accuracy: 0.9444 - val_loss: 0.6427 - val_accuracy: 0.8000 - 17ms/epoch - 6ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0359 - accuracy: 0.9889 - val_loss: 0.6021 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.1112 - accuracy: 0.9778 - val_loss: 0.5908 - val_accuracy: 0.9000 - 16ms/epoch - 5ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0612 - accuracy: 0.9889 - val_loss: 0.5878 - val_accuracy: 0.9333 - 18ms/epoch - 6ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0657 - accuracy: 0.9889 - val_loss: 0.5745 - val_accuracy: 0.8667 - 16ms/epoch - 5ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.1817 - accuracy: 0.9667 - val_loss: 0.5685 - val_accuracy: 0.8667 - 17ms/epoch - 6ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.1523 - accuracy: 0.9444 - val_loss: 0.5519 - val_accuracy: 0.8667 - 18ms/epoch - 6ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.0588 - accuracy: 0.9778 - val_loss: 0.5303 - val_accuracy: 0.9000 - 18ms/epoch - 6ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.5160 - val_accuracy: 0.8667 - 17ms/epoch - 6ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.1060 - accuracy: 0.9556 - val_loss: 0.4965 - val_accuracy: 0.8667 - 16ms/epoch - 5ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0445 - accuracy: 0.9889 - val_loss: 0.4786 - val_accuracy: 0.8667 - 17ms/epoch - 6ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0557 - accuracy: 0.9667 - val_loss: 0.4696 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0675 - accuracy: 0.9667 - val_loss: 0.4586 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.4396 - val_accuracy: 0.9000 - 18ms/epoch - 6ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0398 - accuracy: 0.9889 - val_loss: 0.4133 - val_accuracy: 0.9333 - 27ms/epoch - 9ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0435 - accuracy: 0.9778 - val_loss: 0.3811 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.3628 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0819 - accuracy: 0.9667 - val_loss: 0.3554 - val_accuracy: 0.9333 - 18ms/epoch - 6ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0724 - accuracy: 0.9778 - val_loss: 0.3579 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0447 - accuracy: 0.9778 - val_loss: 0.3491 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.3316 - val_accuracy: 0.9000 - 18ms/epoch - 6ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0912 - accuracy: 0.9778 - val_loss: 0.3067 - val_accuracy: 0.9333 - 18ms/epoch - 6ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0418 - accuracy: 0.9889 - val_loss: 0.2889 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.2822 - val_accuracy: 0.9333 - 15ms/epoch - 5ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.2692 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.2435 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.2367 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 0.9333 - 18ms/epoch - 6ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0906 - accuracy: 0.9778 - val_loss: 0.1946 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0288 - accuracy: 0.9889 - val_loss: 0.1737 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0390 - accuracy: 0.9889 - val_loss: 0.1735 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0789 - accuracy: 0.9556 - val_loss: 0.2236 - val_accuracy: 0.9000 - 18ms/epoch - 6ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0245 - accuracy: 0.9889 - val_loss: 0.2791 - val_accuracy: 0.8333 - 17ms/epoch - 6ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.2963 - val_accuracy: 0.8333 - 18ms/epoch - 6ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0417 - accuracy: 0.9889 - val_loss: 0.2807 - val_accuracy: 0.8333 - 16ms/epoch - 5ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.1051 - accuracy: 0.9778 - val_loss: 0.2366 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0721 - accuracy: 0.9778 - val_loss: 0.2161 - val_accuracy: 0.9000 - 16ms/epoch - 5ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.8667 - 17ms/epoch - 6ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.0823 - accuracy: 0.9556 - val_loss: 0.1717 - val_accuracy: 0.9000 - 16ms/epoch - 5ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0456 - accuracy: 0.9889 - val_loss: 0.1422 - val_accuracy: 0.9333 - 15ms/epoch - 5ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0657 - accuracy: 0.9889 - val_loss: 0.1356 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.0339 - accuracy: 0.9778 - val_loss: 0.0811 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.4861 - accuracy: 0.9333 - val_loss: 0.0669 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0779 - accuracy: 0.9667 - val_loss: 0.1030 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9778 - val_loss: 0.0977 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0906 - accuracy: 0.9667 - val_loss: 0.0863 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.0440 - accuracy: 0.9889 - val_loss: 0.0760 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.1672 - accuracy: 0.9444 - val_loss: 0.0746 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0446 - accuracy: 0.9889 - val_loss: 0.0777 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0879 - accuracy: 0.9556 - val_loss: 0.0712 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0370 - accuracy: 0.9889 - val_loss: 0.0575 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0379 - accuracy: 0.9778 - val_loss: 0.0466 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0317 - accuracy: 0.9778 - val_loss: 0.0390 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0945 - accuracy: 0.9667 - val_loss: 0.0344 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0433 - accuracy: 0.9889 - val_loss: 0.0295 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0361 - accuracy: 0.9778 - val_loss: 0.0232 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0229 - accuracy: 0.9889 - val_loss: 0.0199 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0321 - accuracy: 0.9889 - val_loss: 0.0189 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0355 - accuracy: 0.9778 - val_loss: 0.0162 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.1034 - accuracy: 0.9889 - val_loss: 0.0143 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0971 - accuracy: 0.9778 - val_loss: 0.0163 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0195 - accuracy: 0.9889 - val_loss: 0.0211 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0287 - accuracy: 0.9889 - val_loss: 0.0212 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0266 - accuracy: 0.9889 - val_loss: 0.0294 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.1537 - accuracy: 0.9556 - val_loss: 0.0315 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0301 - accuracy: 0.9778 - val_loss: 0.0220 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.0224 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0969 - accuracy: 0.9889 - val_loss: 0.0218 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0311 - accuracy: 0.9889 - val_loss: 0.0191 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000 - 27ms/epoch - 9ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0989 - accuracy: 0.9556 - val_loss: 0.0220 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.0507 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0345 - accuracy: 0.9889 - val_loss: 0.0594 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0477 - accuracy: 0.9889 - val_loss: 0.0621 - val_accuracy: 0.9667 - 17ms/epoch - 6ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0439 - accuracy: 0.9778 - val_loss: 0.0619 - val_accuracy: 0.9667 - 18ms/epoch - 6ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0252 - accuracy: 0.9889 - val_loss: 0.0323 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0487 - accuracy: 0.9889 - val_loss: 0.0189 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0558 - accuracy: 0.9778 - val_loss: 0.0212 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0224 - accuracy: 0.9889 - val_loss: 0.0372 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0930 - accuracy: 0.9556 - val_loss: 0.0389 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.1437 - accuracy: 0.9444 - val_loss: 0.0279 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0816 - accuracy: 0.9667 - val_loss: 0.0185 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0589 - accuracy: 0.9889 - val_loss: 0.0173 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.2440 - accuracy: 0.9556 - val_loss: 0.0180 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0695 - accuracy: 0.9889 - val_loss: 0.0174 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0587 - accuracy: 0.9778 - val_loss: 0.0183 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.1657 - accuracy: 0.9667 - val_loss: 0.0237 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0463 - accuracy: 0.9889 - val_loss: 0.0543 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9000 - 16ms/epoch - 5ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9000 - 16ms/epoch - 5ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0483 - accuracy: 0.9889 - val_loss: 0.1271 - val_accuracy: 0.9000 - 17ms/epoch - 6ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9667 - 15ms/epoch - 5ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.1534 - accuracy: 0.9556 - val_loss: 0.0696 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0348 - accuracy: 0.9889 - val_loss: 0.0890 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0794 - accuracy: 0.9778 - val_loss: 0.0786 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0393 - accuracy: 0.9889 - val_loss: 0.0458 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0475 - accuracy: 0.9889 - val_loss: 0.0255 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0614 - accuracy: 0.9667 - val_loss: 0.0166 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0857 - accuracy: 0.9667 - val_loss: 0.0246 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0257 - accuracy: 0.9889 - val_loss: 0.0617 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9778 - val_loss: 0.0947 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0464 - accuracy: 0.9778 - val_loss: 0.0889 - val_accuracy: 0.9333 - 18ms/epoch - 6ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0791 - accuracy: 0.9778 - val_loss: 0.0560 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0860 - accuracy: 0.9667 - val_loss: 0.0329 - val_accuracy: 1.0000 - 27ms/epoch - 9ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0340 - accuracy: 0.9889 - val_loss: 0.0140 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0602 - accuracy: 0.9778 - val_loss: 0.0125 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0177 - accuracy: 0.9889 - val_loss: 0.0106 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0185 - accuracy: 0.9889 - val_loss: 0.0132 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0569 - accuracy: 0.9889 - val_loss: 0.0201 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0212 - accuracy: 0.9889 - val_loss: 0.0215 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.1247 - accuracy: 0.9667 - val_loss: 0.0120 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0321 - accuracy: 0.9778 - val_loss: 0.0471 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0996 - accuracy: 0.9667 - val_loss: 0.0716 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9667 - 17ms/epoch - 6ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0488 - accuracy: 0.9778 - val_loss: 0.0476 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0696 - accuracy: 0.9667 - val_loss: 0.0336 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0284 - accuracy: 0.9889 - val_loss: 0.0350 - val_accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0240 - accuracy: 0.9889 - val_loss: 0.0407 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0437 - accuracy: 0.9889 - val_loss: 0.0625 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0428 - accuracy: 0.9889 - val_loss: 0.0943 - val_accuracy: 0.9333 - 17ms/epoch - 6ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0419 - accuracy: 0.9889 - val_loss: 0.1257 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0396 - accuracy: 0.9889 - val_loss: 0.1459 - val_accuracy: 0.9000 - 16ms/epoch - 5ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9333 - 16ms/epoch - 5ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0452 - accuracy: 0.9778 - val_loss: 0.1105 - val_accuracy: 0.9333 - 15ms/epoch - 5ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0474 - accuracy: 0.9889 - val_loss: 0.0646 - val_accuracy: 0.9667 - 16ms/epoch - 5ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0578 - accuracy: 0.9889 - val_loss: 0.0177 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - 16ms/epoch - 5ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(batched_history, 'accuracy')

# %%
plot_metric(batched_history, 'loss')

# %%
batched_model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1827 - accuracy: 0.9000 - 14ms/epoch - 14ms/step
# [0.18273013830184937, 0.8999999761581421]
